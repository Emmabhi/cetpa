# %%
from sklearn.datasets import make_blobs

# %%
x,y=make_blobs(n_samples=400,centers=5,cluster_std=0.60,random_state=0)

# %% [markdown]
# n_samples = number of samples by default 100
#
#
# n_features = number of features for each sample by default 2
#
# centres are centres if n_sample is int and centre is none by default 3 centres are generated
#
# cluster_std= standard deviation of clusters  by default 1
#
# centre_box = pair of (min,max) boundation for centres
#
# shuffle = boolean value for shuffling by default true
#
# random_state = determines random number generation for dataset creation
#
#
# return_centers = return the center of each cluster by default false

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.cluster import  KMeans

# %%
plt.scatter(x[:,0],x[:,1],s=20);
plt.show()

# %%
kmeans = KMeans(n_clusters =5)
kmeans.fit(x)
y_kmeans = kmeans.predict(x)

# %%
plt.scatter(x[:,0],x[:,1],c=y_kmeans,s=20,cmap='summer')
centers = kmeans.cluster_centers_
plt.scatter(centers[:,0],centers[:,1],c="blue",s=100,alpha=0.9);
plt.show()
